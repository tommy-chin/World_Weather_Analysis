# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1833899c54d0c5474f6880c2e2426f6b

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | hammerfest
# Processing Record 3 of Set 1 | namibe
# Processing Record 4 of Set 1 | barinas
# Processing Record 5 of Set 1 | lorengau
# Processing Record 6 of Set 1 | charleston
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | locri
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | itaituba
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | san quintin
# Processing Record 14 of Set 1 | aklavik
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | ouadda
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | te anau
# Processing Record 23 of Set 1 | adrar
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | lompoc
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | torbay
# Processing Record 28 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 1 | coromandel
# Processing Record 30 of Set 1 | lanzhou
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | bethanien
# Processing Record 33 of Set 1 | aitape
# Processing Record 34 of Set 1 | sao joao da barra
# Processing Record 35 of Set 1 | lahaina
# Processing Record 36 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 1 | husavik
# Processing Record 38 of Set 1 | taoudenni
# Processing Record 39 of Set 1 | biltine
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | vila franca do campo
# Processing Record 44 of Set 1 | sitka
# Processing Record 45 of Set 1 | pacific grove
# Processing Record 46 of Set 1 | bathsheba
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | maceio
# Processing Record 49 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | novoagansk
# Processing Record 1 of Set 2 | matay
# Processing Record 2 of Set 2 | arlit
# Processing Record 3 of Set 2 | grindavik
# Processing Record 4 of Set 2 | zambezi
# Processing Record 5 of Set 2 | esperance
# Processing Record 6 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 2 | karwar
# Processing Record 8 of Set 2 | geraldton
# Processing Record 9 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 2 | shaunavon
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 2 | nishihara
# Processing Record 14 of Set 2 | mahebourg
# Processing Record 15 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 16 of Set 2 | general roca
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | rio gallegos
# Processing Record 20 of Set 2 | ostrovnoy
# Processing Record 21 of Set 2 | samarai
# Processing Record 22 of Set 2 | karratha
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 2 | dolores
# Processing Record 28 of Set 2 | souillac
# Processing Record 29 of Set 2 | sioux lookout
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | imeni poliny osipenko
# Processing Record 32 of Set 2 | sazonovo
# Processing Record 33 of Set 2 | kearney
# Processing Record 34 of Set 2 | constitucion
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | whitehorse
# Processing Record 38 of Set 2 | batsfjord
# Processing Record 39 of Set 2 | airai
# Processing Record 40 of Set 2 | mahibadhoo
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | dubbo
# Processing Record 43 of Set 2 | shingu
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 2 | denpasar
# Processing Record 47 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | urubamba
# Processing Record 50 of Set 2 | corn island
# Processing Record 1 of Set 3 | margate
# Processing Record 2 of Set 3 | cidreira
# Processing Record 3 of Set 3 | katsuura
# Processing Record 4 of Set 3 | tuatapere
# Processing Record 5 of Set 3 | ibra
# Processing Record 6 of Set 3 | cambyreta
# City not found. Skipping...
# Processing Record 7 of Set 3 | morgan city
# Processing Record 8 of Set 3 | hami
# Processing Record 9 of Set 3 | madera
# Processing Record 10 of Set 3 | hamilton
# Processing Record 11 of Set 3 | goderich
# Processing Record 12 of Set 3 | marawi
# Processing Record 13 of Set 3 | road town
# Processing Record 14 of Set 3 | clermont
# Processing Record 15 of Set 3 | yerbogachen
# Processing Record 16 of Set 3 | grenfell
# Processing Record 17 of Set 3 | saint-philippe
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | laguna
# Processing Record 20 of Set 3 | vaini
# Processing Record 21 of Set 3 | nata
# Processing Record 22 of Set 3 | sabalgarh
# Processing Record 23 of Set 3 | cherskiy
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | sorland
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | kamareddi
# Processing Record 30 of Set 3 | fukue
# Processing Record 31 of Set 3 | clyde river
# Processing Record 32 of Set 3 | jalu
# Processing Record 33 of Set 3 | abeche
# Processing Record 34 of Set 3 | caravelas
# Processing Record 35 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 3 | gwadar
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | muroto
# Processing Record 39 of Set 3 | kjollefjord
# Processing Record 40 of Set 3 | kavieng
# Processing Record 41 of Set 3 | lukulu
# Processing Record 42 of Set 3 | malazgirt
# Processing Record 43 of Set 3 | kruisfontein
# Processing Record 44 of Set 3 | mount gambier
# Processing Record 45 of Set 3 | beringovskiy
# Processing Record 46 of Set 3 | puerto ayora
# Processing Record 47 of Set 3 | yumen
# Processing Record 48 of Set 3 | burns lake
# Processing Record 49 of Set 3 | lebu
# Processing Record 50 of Set 3 | port blair
# Processing Record 1 of Set 4 | mingshui
# Processing Record 2 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 4 | tuktoyaktuk
# Processing Record 4 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 5 of Set 4 | de-kastri
# Processing Record 6 of Set 4 | noumea
# Processing Record 7 of Set 4 | jamestown
# Processing Record 8 of Set 4 | portland
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | alugan
# Processing Record 12 of Set 4 | marsh harbour
# Processing Record 13 of Set 4 | kuching
# Processing Record 14 of Set 4 | cape town
# Processing Record 15 of Set 4 | les cayes
# Processing Record 16 of Set 4 | sassandra
# Processing Record 17 of Set 4 | kavaratti
# Processing Record 18 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 4 | slave lake
# Processing Record 20 of Set 4 | tacuarembo
# Processing Record 21 of Set 4 | hailey
# Processing Record 22 of Set 4 | port-gentil
# Processing Record 23 of Set 4 | esfarayen
# Processing Record 24 of Set 4 | sisophon
# Processing Record 25 of Set 4 | darab
# Processing Record 26 of Set 4 | flinders
# Processing Record 27 of Set 4 | dunedin
# Processing Record 28 of Set 4 | luderitz
# Processing Record 29 of Set 4 | gravdal
# Processing Record 30 of Set 4 | la palma
# Processing Record 31 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | mombetsu
# Processing Record 35 of Set 4 | ola
# Processing Record 36 of Set 4 | almeirim
# Processing Record 37 of Set 4 | batticaloa
# Processing Record 38 of Set 4 | tazovskiy
# Processing Record 39 of Set 4 | provideniya
# Processing Record 40 of Set 4 | monrovia
# Processing Record 41 of Set 4 | labuhan
# Processing Record 42 of Set 4 | panguna
# Processing Record 43 of Set 4 | itarema
# Processing Record 44 of Set 4 | lata
# Processing Record 45 of Set 4 | fort nelson
# Processing Record 46 of Set 4 | marsa matruh
# Processing Record 47 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 48 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 4 | makakilo city
# Processing Record 50 of Set 4 | tonstad
# Processing Record 1 of Set 5 | namatanai
# Processing Record 2 of Set 5 | barranca
# Processing Record 3 of Set 5 | boguchany
# Processing Record 4 of Set 5 | sao jose do egito
# Processing Record 5 of Set 5 | palauig
# Processing Record 6 of Set 5 | bilma
# Processing Record 7 of Set 5 | yellowknife
# Processing Record 8 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 5 | camacha
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | cururupu
# Processing Record 13 of Set 5 | bilibino
# Processing Record 14 of Set 5 | berdigestyakh
# Processing Record 15 of Set 5 | aleksandrov gay
# Processing Record 16 of Set 5 | ried
# Processing Record 17 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 5 | glazov
# Processing Record 19 of Set 5 | samandag
# Processing Record 20 of Set 5 | ginowan
# Processing Record 21 of Set 5 | conde
# Processing Record 22 of Set 5 | antofagasta
# Processing Record 23 of Set 5 | huilong
# Processing Record 24 of Set 5 | hasaki
# Processing Record 25 of Set 5 | maura
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | norman wells
# Processing Record 28 of Set 5 | the valley
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | harper
# Processing Record 31 of Set 5 | severo-yeniseyskiy
# Processing Record 32 of Set 5 | sakakah
# Processing Record 33 of Set 5 | cairns
# Processing Record 34 of Set 5 | along
# Processing Record 35 of Set 5 | sao jose da coroa grande
# Processing Record 36 of Set 5 | san patricio
# Processing Record 37 of Set 5 | lagoa
# Processing Record 38 of Set 5 | san policarpo
# Processing Record 39 of Set 5 | san juan
# Processing Record 40 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 5 | springdale
# Processing Record 42 of Set 5 | khatanga
# Processing Record 43 of Set 5 | sambava
# Processing Record 44 of Set 5 | mundo nuevo
# Processing Record 45 of Set 5 | edgewater
# Processing Record 46 of Set 5 | poum
# Processing Record 47 of Set 5 | sayat
# Processing Record 48 of Set 5 | phuket
# Processing Record 49 of Set 5 | san vicente
# Processing Record 50 of Set 5 | lomonosov
# Processing Record 1 of Set 6 | ploemeur
# Processing Record 2 of Set 6 | kununurra
# Processing Record 3 of Set 6 | muros
# Processing Record 4 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 5 of Set 6 | mindif
# Processing Record 6 of Set 6 | muisne
# Processing Record 7 of Set 6 | kovdor
# Processing Record 8 of Set 6 | roura
# Processing Record 9 of Set 6 | melbourne
# Processing Record 10 of Set 6 | makung
# City not found. Skipping...
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | grand gaube
# Processing Record 13 of Set 6 | bandarbeyla
# Processing Record 14 of Set 6 | srednekolymsk
# Processing Record 15 of Set 6 | bengkulu
# Processing Record 16 of Set 6 | saint anthony
# Processing Record 17 of Set 6 | puerto baquerizo moreno
# Processing Record 18 of Set 6 | am timan
# Processing Record 19 of Set 6 | xicotencatl
# Processing Record 20 of Set 6 | takoradi
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | zlobin
# Processing Record 23 of Set 6 | leningradskiy
# Processing Record 24 of Set 6 | xam nua
# Processing Record 25 of Set 6 | eyl
# Processing Record 26 of Set 6 | barzas
# Processing Record 27 of Set 6 | praia da vitoria
# Processing Record 28 of Set 6 | post falls
# Processing Record 29 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 6 | port hardy
# Processing Record 31 of Set 6 | znamenskoye
# Processing Record 32 of Set 6 | esna
# Processing Record 33 of Set 6 | quesnel
# Processing Record 34 of Set 6 | victoria
# Processing Record 35 of Set 6 | coquimbo
# Processing Record 36 of Set 6 | nikolsk
# Processing Record 37 of Set 6 | severo-kurilsk
# Processing Record 38 of Set 6 | barcelos
# Processing Record 39 of Set 6 | berlevag
# Processing Record 40 of Set 6 | zhigansk
# Processing Record 41 of Set 6 | montepuez
# Processing Record 42 of Set 6 | beyneu
# Processing Record 43 of Set 6 | raisinghnagar
# Processing Record 44 of Set 6 | faya
# Processing Record 45 of Set 6 | ilulissat
# Processing Record 46 of Set 6 | lithgow
# Processing Record 47 of Set 6 | bouloupari
# Processing Record 48 of Set 6 | dawlatabad
# Processing Record 49 of Set 6 | kvarkeno
# Processing Record 50 of Set 6 | mangai
# Processing Record 1 of Set 7 | benin
# Processing Record 2 of Set 7 | arraial do cabo
# Processing Record 3 of Set 7 | vardo
# Processing Record 4 of Set 7 | cabo san lucas
# Processing Record 5 of Set 7 | quetzaltepec
# City not found. Skipping...
# Processing Record 6 of Set 7 | grand forks
# Processing Record 7 of Set 7 | yar-sale
# Processing Record 8 of Set 7 | saskylakh
# Processing Record 9 of Set 7 | zeya
# Processing Record 10 of Set 7 | guerrero negro
# Processing Record 11 of Set 7 | talnakh
# Processing Record 12 of Set 7 | shimoda
# Processing Record 13 of Set 7 | mineiros
# Processing Record 14 of Set 7 | sola
# Processing Record 15 of Set 7 | aksu
# Processing Record 16 of Set 7 | comodoro rivadavia
# Processing Record 17 of Set 7 | ponta delgada
# Processing Record 18 of Set 7 | san-pedro
# Processing Record 19 of Set 7 | anloga
# Processing Record 20 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 7 | yashan
# Processing Record 22 of Set 7 | chuy
# Processing Record 23 of Set 7 | najran
# Processing Record 24 of Set 7 | umuarama
# Processing Record 25 of Set 7 | nelson bay
# Processing Record 26 of Set 7 | faanui
# Processing Record 27 of Set 7 | tokur
# Processing Record 28 of Set 7 | dikson
# Processing Record 29 of Set 7 | oranjemund
# Processing Record 30 of Set 7 | avera
# Processing Record 31 of Set 7 | hailar
# Processing Record 32 of Set 7 | borsele
# Processing Record 33 of Set 7 | tiksi
# Processing Record 34 of Set 7 | sinnamary
# Processing Record 35 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 7 | andarab
# City not found. Skipping...
# Processing Record 37 of Set 7 | milkovo
# Processing Record 38 of Set 7 | hermiston
# Processing Record 39 of Set 7 | salalah
# Processing Record 40 of Set 7 | kirakira
# Processing Record 41 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 7 | codrington
# Processing Record 43 of Set 7 | castro
# Processing Record 44 of Set 7 | la ronge
# Processing Record 45 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 46 of Set 7 | alyangula
# Processing Record 47 of Set 7 | san luis
# Processing Record 48 of Set 7 | meaford
# Processing Record 49 of Set 7 | hervey bay
# Processing Record 50 of Set 7 | buala
# Processing Record 1 of Set 8 | burnie
# Processing Record 2 of Set 8 | pendleton
# Processing Record 3 of Set 8 | tilichiki
# Processing Record 4 of Set 8 | viedma
# Processing Record 5 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 8 | tugulym
# Processing Record 7 of Set 8 | chapais
# Processing Record 8 of Set 8 | hambantota
# Processing Record 9 of Set 8 | amahai
# Processing Record 10 of Set 8 | college
# Processing Record 11 of Set 8 | porangatu
# Processing Record 12 of Set 8 | tabuk
# Processing Record 13 of Set 8 | lakes entrance
# Processing Record 14 of Set 8 | walvis bay
# Processing Record 15 of Set 8 | asau
# Processing Record 16 of Set 8 | touros
# Processing Record 17 of Set 8 | shadrinsk
# Processing Record 18 of Set 8 | ormstown
# Processing Record 19 of Set 8 | longyearbyen
# Processing Record 20 of Set 8 | palmer
# Processing Record 21 of Set 8 | sur
# Processing Record 22 of Set 8 | necochea
# Processing Record 23 of Set 8 | ribeira grande
# Processing Record 24 of Set 8 | canton
# Processing Record 25 of Set 8 | biak
# Processing Record 26 of Set 8 | itoman
# Processing Record 27 of Set 8 | birao
# Processing Record 28 of Set 8 | carballo
# Processing Record 29 of Set 8 | ahipara
# Processing Record 30 of Set 8 | whitefish
# Processing Record 31 of Set 8 | sabang
# Processing Record 32 of Set 8 | port keats
# Processing Record 33 of Set 8 | imperia
# Processing Record 34 of Set 8 | netrakona
# Processing Record 35 of Set 8 | nabire
# Processing Record 36 of Set 8 | gat
# Processing Record 37 of Set 8 | stilfontein
# Processing Record 38 of Set 8 | paka
# Processing Record 39 of Set 8 | yining
# Processing Record 40 of Set 8 | veraval
# Processing Record 41 of Set 8 | koungou
# Processing Record 42 of Set 8 | kastornoye
# Processing Record 43 of Set 8 | guanica
# Processing Record 44 of Set 8 | heihe
# Processing Record 45 of Set 8 | daru
# Processing Record 46 of Set 8 | masindi
# Processing Record 47 of Set 8 | erenhot
# Processing Record 48 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 49 of Set 8 | narsaq
# Processing Record 50 of Set 8 | saint george
# Processing Record 1 of Set 9 | kokstad
# Processing Record 2 of Set 9 | lazaro cardenas
# Processing Record 3 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 9 | santa elena
# Processing Record 5 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 9 | deputatskiy
# Processing Record 7 of Set 9 | sao gabriel da cachoeira
# Processing Record 8 of Set 9 | tarko-sale
# Processing Record 9 of Set 9 | naze
# Processing Record 10 of Set 9 | ponta do sol
# Processing Record 11 of Set 9 | tura
# Processing Record 12 of Set 9 | nuevo casas grandes
# Processing Record 13 of Set 9 | kamaishi
# Processing Record 14 of Set 9 | hithadhoo
# Processing Record 15 of Set 9 | la asuncion
# Processing Record 16 of Set 9 | coleraine
# Processing Record 17 of Set 9 | mhango
# Processing Record 18 of Set 9 | tynda
# Processing Record 19 of Set 9 | genhe
# Processing Record 20 of Set 9 | rawson
# Processing Record 21 of Set 9 | condega
# Processing Record 22 of Set 9 | gloversville
# Processing Record 23 of Set 9 | henties bay
# Processing Record 24 of Set 9 | progreso
# Processing Record 25 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 9 | eureka
# Processing Record 27 of Set 9 | shiringushi
# Processing Record 28 of Set 9 | kangalassy
# Processing Record 29 of Set 9 | gadarwara
# Processing Record 30 of Set 9 | vestmannaeyjar
# Processing Record 31 of Set 9 | juba
# Processing Record 32 of Set 9 | anadyr
# Processing Record 33 of Set 9 | warora
# Processing Record 34 of Set 9 | qasigiannguit
# Processing Record 35 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 9 | sibut
# Processing Record 37 of Set 9 | tanggu
# Processing Record 38 of Set 9 | tabukiniberu
# City not found. Skipping...
# Processing Record 39 of Set 9 | tonota
# Processing Record 40 of Set 9 | cayenne
# Processing Record 41 of Set 9 | kyabram
# Processing Record 42 of Set 9 | mandalgovi
# Processing Record 43 of Set 9 | mogok
# Processing Record 44 of Set 9 | shelburne
# Processing Record 45 of Set 9 | isangel
# Processing Record 46 of Set 9 | cascais
# Processing Record 47 of Set 9 | vao
# Processing Record 48 of Set 9 | hebertville
# City not found. Skipping...
# Processing Record 49 of Set 9 | burica
# City not found. Skipping...
# Processing Record 50 of Set 9 | belmonte
# Processing Record 1 of Set 10 | gao
# Processing Record 2 of Set 10 | challans
# Processing Record 3 of Set 10 | odweyne
# Processing Record 4 of Set 10 | kollumerland
# City not found. Skipping...
# Processing Record 5 of Set 10 | lagdo
# Processing Record 6 of Set 10 | usinsk
# Processing Record 7 of Set 10 | kankon
# Processing Record 8 of Set 10 | pisco
# Processing Record 9 of Set 10 | rio grande
# Processing Record 10 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 10 | port lincoln
# Processing Record 12 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 10 | rock springs
# Processing Record 14 of Set 10 | prescott
# Processing Record 15 of Set 10 | egvekinot
# Processing Record 16 of Set 10 | nome
# Processing Record 17 of Set 10 | zheleznodorozhnyy
# Processing Record 18 of Set 10 | mitsamiouli
# Processing Record 19 of Set 10 | maryville
# Processing Record 20 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 21 of Set 10 | ajdabiya
# Processing Record 22 of Set 10 | manokwari
# Processing Record 23 of Set 10 | lardos
# Processing Record 24 of Set 10 | orlik
# Processing Record 25 of Set 10 | manacapuru
# Processing Record 26 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 10 | abnub
# Processing Record 28 of Set 10 | hualmay
# Processing Record 29 of Set 10 | campo grande
# Processing Record 30 of Set 10 | songea
# Processing Record 31 of Set 10 | bluefields
# Processing Record 32 of Set 10 | kaka
# Processing Record 33 of Set 10 | kieta
# Processing Record 34 of Set 10 | parkes
# Processing Record 35 of Set 10 | vrindavan
# Processing Record 36 of Set 10 | porto novo
# Processing Record 37 of Set 10 | linhares
# Processing Record 38 of Set 10 | barentu
# Processing Record 39 of Set 10 | kinarut
# Processing Record 40 of Set 10 | troitskoye
# Processing Record 41 of Set 10 | jefferson city
# Processing Record 42 of Set 10 | iqaluit
# Processing Record 43 of Set 10 | nouadhibou
# Processing Record 44 of Set 10 | aras
# Processing Record 45 of Set 10 | kilifi
# Processing Record 46 of Set 10 | balykshi
# Processing Record 47 of Set 10 | hobyo
# Processing Record 48 of Set 10 | kaeo
# Processing Record 49 of Set 10 | kahului
# Processing Record 50 of Set 10 | matagami
# Processing Record 1 of Set 11 | basco
# Processing Record 2 of Set 11 | svetlyy
# Processing Record 3 of Set 11 | alta floresta
# Processing Record 4 of Set 11 | hovin
# Processing Record 5 of Set 11 | ambovombe
# Processing Record 6 of Set 11 | derzhavinsk
# Processing Record 7 of Set 11 | harlingen
# Processing Record 8 of Set 11 | dingle
# Processing Record 9 of Set 11 | diamantina
# Processing Record 10 of Set 11 | vigrestad
# Processing Record 11 of Set 11 | trincomalee
# Processing Record 12 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 13 of Set 11 | northam
# Processing Record 14 of Set 11 | gamba
# Processing Record 15 of Set 11 | aswan
# Processing Record 16 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 11 | silute
# Processing Record 18 of Set 11 | himora
# City not found. Skipping...
# Processing Record 19 of Set 11 | ayios matthaios
# City not found. Skipping...
# Processing Record 20 of Set 11 | xichang
# Processing Record 21 of Set 11 | koratla
# Processing Record 22 of Set 11 | damietta
# Processing Record 23 of Set 11 | sampit
# Processing Record 24 of Set 11 | makarov
# Processing Record 25 of Set 11 | teopisca
# Processing Record 26 of Set 11 | emerald
# Processing Record 27 of Set 11 | plattling
# Processing Record 28 of Set 11 | weligama
# Processing Record 29 of Set 11 | mancora
# Processing Record 30 of Set 11 | acin
# City not found. Skipping...
# Processing Record 31 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 11 | karpogory
# Processing Record 33 of Set 11 | martinsville
# Processing Record 34 of Set 11 | laurel
# Processing Record 35 of Set 11 | zasheyek
# Processing Record 36 of Set 11 | capao da canoa
# Processing Record 37 of Set 11 | kharp
# Processing Record 38 of Set 11 | kuah
# Processing Record 39 of Set 11 | yabrud
# Processing Record 40 of Set 11 | sarkand
# Processing Record 41 of Set 11 | norden
# Processing Record 42 of Set 11 | camargo
# Processing Record 43 of Set 11 | agadez
# Processing Record 44 of Set 11 | amposta
# Processing Record 45 of Set 11 | yeehaw junction
# City not found. Skipping...
# Processing Record 46 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 47 of Set 11 | palmares do sul
# Processing Record 48 of Set 11 | jiuquan
# Processing Record 49 of Set 11 | dzhebariki-khaya
# Processing Record 50 of Set 11 | viransehir
# Processing Record 1 of Set 12 | acapulco
# Processing Record 2 of Set 12 | olonets
# Processing Record 3 of Set 12 | tchibanga
# Processing Record 4 of Set 12 | coihaique
# Processing Record 5 of Set 12 | shugurovo
# Processing Record 6 of Set 12 | mpongwe
# Processing Record 7 of Set 12 | lavrentiya
# Processing Record 8 of Set 12 | bondo
# Processing Record 9 of Set 12 | mehamn
# Processing Record 10 of Set 12 | edwardsville
# Processing Record 11 of Set 12 | doka
# Processing Record 12 of Set 12 | garissa
# Processing Record 13 of Set 12 | le port
# Processing Record 14 of Set 12 | yarmouth
# Processing Record 15 of Set 12 | sosnovo-ozerskoye
# Processing Record 16 of Set 12 | kovur
# Processing Record 17 of Set 12 | torit
# Processing Record 18 of Set 12 | lajedo
# Processing Record 19 of Set 12 | gazni
# City not found. Skipping...
# Processing Record 20 of Set 12 | lahat
# Processing Record 21 of Set 12 | sabha
# Processing Record 22 of Set 12 | novyy urengoy
# Processing Record 23 of Set 12 | kadoshkino
# Processing Record 24 of Set 12 | alice springs
# Processing Record 25 of Set 12 | merritt island
# Processing Record 26 of Set 12 | voh
# Processing Record 27 of Set 12 | beian
# Processing Record 28 of Set 12 | sangar
# Processing Record 29 of Set 12 | at-bashi
# Processing Record 30 of Set 12 | cartagena
# Processing Record 31 of Set 12 | bo phloi
# Processing Record 32 of Set 12 | havelock
# Processing Record 33 of Set 12 | ginda
# Processing Record 34 of Set 12 | metro
# Processing Record 35 of Set 12 | tingi
# Processing Record 36 of Set 12 | flin flon
# Processing Record 37 of Set 12 | jiayuguan
# Processing Record 38 of Set 12 | poco das trincheiras
# Processing Record 39 of Set 12 | havre-saint-pierre
# Processing Record 40 of Set 12 | coolum beach
# Processing Record 41 of Set 12 | ust-maya
# Processing Record 42 of Set 12 | ugoofaaru
# Processing Record 43 of Set 12 | nakhon phanom
# Processing Record 44 of Set 12 | george town
# Processing Record 45 of Set 12 | moron
# Processing Record 46 of Set 12 | katha
# City not found. Skipping...
# Processing Record 47 of Set 12 | pangnirtung
# Processing Record 48 of Set 12 | lewistown
# Processing Record 49 of Set 12 | orocovis
# Processing Record 50 of Set 12 | meulaboh
# Processing Record 1 of Set 13 | aracati
# Processing Record 2 of Set 13 | launceston
# Processing Record 3 of Set 13 | korla
# Processing Record 4 of Set 13 | bowen
# Processing Record 5 of Set 13 | kattivakkam
# Processing Record 6 of Set 13 | nyrob
# Processing Record 7 of Set 13 | teguise
# Processing Record 8 of Set 13 | kallifitos
# Processing Record 9 of Set 13 | marienburg
# Processing Record 10 of Set 13 | mana
# Processing Record 11 of Set 13 | cabedelo
# Processing Record 12 of Set 13 | byron bay
# Processing Record 13 of Set 13 | sungai kolok
# City not found. Skipping...
# Processing Record 14 of Set 13 | watertown
# Processing Record 15 of Set 13 | pregassona
# Processing Record 16 of Set 13 | kpandae
# Processing Record 17 of Set 13 | saint-joseph
# Processing Record 18 of Set 13 | papetoai
# Processing Record 19 of Set 13 | surt
# Processing Record 20 of Set 13 | ambilobe
# Processing Record 21 of Set 13 | sohbatpur
# Processing Record 22 of Set 13 | leh
# Processing Record 23 of Set 13 | half moon bay
# Processing Record 24 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 13 | janakkala
# Processing Record 26 of Set 13 | belyy yar
# Processing Record 27 of Set 13 | san clemente
# Processing Record 28 of Set 13 | payakumbuh
# Processing Record 29 of Set 13 | oum hadjer
# Processing Record 30 of Set 13 | banda aceh
# Processing Record 31 of Set 13 | beloha
# Processing Record 32 of Set 13 | san jose
# Processing Record 33 of Set 13 | olafsvik
# Processing Record 34 of Set 13 | kokopo
# Processing Record 35 of Set 13 | dongsheng
# Processing Record 36 of Set 13 | arman
# Processing Record 37 of Set 13 | khammam
# Processing Record 38 of Set 13 | omsukchan
# Processing Record 39 of Set 13 | dongzhen
# Processing Record 40 of Set 13 | sofiysk
# City not found. Skipping...
# Processing Record 41 of Set 13 | hirara
# Processing Record 42 of Set 13 | jalaun
# Processing Record 43 of Set 13 | monte alegre
# Processing Record 44 of Set 13 | rustenburg
# Processing Record 45 of Set 13 | peniche
# Processing Record 46 of Set 13 | kabalo
# Processing Record 47 of Set 13 | bansang
# Processing Record 48 of Set 13 | dudinka
# Processing Record 49 of Set 13 | zhangjiakou
# Processing Record 50 of Set 13 | masuda
# Processing Record 1 of Set 14 | ojinaga
# Processing Record 2 of Set 14 | viseu
# Processing Record 3 of Set 14 | charters towers
# Processing Record 4 of Set 14 | lufilufi
# Processing Record 5 of Set 14 | hofn
# Processing Record 6 of Set 14 | eyrarbakki
# Processing Record 7 of Set 14 | pitanga
# Processing Record 8 of Set 14 | labytnangi
# Processing Record 9 of Set 14 | vanimo
# Processing Record 10 of Set 14 | boca do acre
# Processing Record 11 of Set 14 | paita
# Processing Record 12 of Set 14 | churapcha
# Processing Record 13 of Set 14 | dobsice
# Processing Record 14 of Set 14 | kargasok
# Processing Record 15 of Set 14 | broken hill
# Processing Record 16 of Set 14 | delta del tigre
# Processing Record 17 of Set 14 | seoul
# Processing Record 18 of Set 14 | mumford
# Processing Record 19 of Set 14 | okhotsk
# Processing Record 20 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 14 | tombouctou
# Processing Record 22 of Set 14 | lima
# Processing Record 23 of Set 14 | terre-de-bas
# Processing Record 24 of Set 14 | adelaide
# Processing Record 25 of Set 14 | liku
# Processing Record 26 of Set 14 | deer lake
# Processing Record 27 of Set 14 | madimba
# Processing Record 28 of Set 14 | pitimbu
# Processing Record 29 of Set 14 | coffs harbour
# Processing Record 30 of Set 14 | yola
# Processing Record 31 of Set 14 | hered
# Processing Record 32 of Set 14 | pucallpa
# Processing Record 33 of Set 14 | berea
# Processing Record 34 of Set 14 | puerto maldonado
# Processing Record 35 of Set 14 | manadhoo
# Processing Record 36 of Set 14 | urulga
# City not found. Skipping...
# Processing Record 37 of Set 14 | duz
# City not found. Skipping...
# Processing Record 38 of Set 14 | keuruu
# Processing Record 39 of Set 14 | varhaug
# Processing Record 40 of Set 14 | kalmunai
# Processing Record 41 of Set 14 | fereydunshahr
# Processing Record 42 of Set 14 | la rioja
# Processing Record 43 of Set 14 | marabba
# Processing Record 44 of Set 14 | loandjili
# Processing Record 45 of Set 14 | tounan
# City not found. Skipping...
# Processing Record 46 of Set 14 | talaya
# Processing Record 47 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 14 | saint-pierre
# Processing Record 49 of Set 14 | lesosibirsk
# Processing Record 50 of Set 14 | oktyabrskiy
# Processing Record 1 of Set 15 | grayvoron
# Processing Record 2 of Set 15 | cockburn town
# Processing Record 3 of Set 15 | shahr-e kord
# Processing Record 4 of Set 15 | batemans bay
# Processing Record 5 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 15 | ndjole
# Processing Record 7 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 8 of Set 15 | tamandare
# Processing Record 9 of Set 15 | smidovich
# Processing Record 10 of Set 15 | gornoye loo
# Processing Record 11 of Set 15 | charlottesville
# Processing Record 12 of Set 15 | saint-augustin
# Processing Record 13 of Set 15 | loukisia
# Processing Record 14 of Set 15 | santa vitoria do palmar
# Processing Record 15 of Set 15 | tumbagaan
# Processing Record 16 of Set 15 | andros
# Processing Record 17 of Set 15 | mattru
# Processing Record 18 of Set 15 | santa isabel do rio negro
# Processing Record 19 of Set 15 | lodwar
# Processing Record 20 of Set 15 | dalkola
# Processing Record 21 of Set 15 | minudasht
# Processing Record 22 of Set 15 | manta
# Processing Record 23 of Set 15 | cecina
# Processing Record 24 of Set 15 | kupang
# Processing Record 25 of Set 15 | sokoni
# Processing Record 26 of Set 15 | ferrol
# Processing Record 27 of Set 15 | thakurgaon
# Processing Record 28 of Set 15 | waipawa
# Processing Record 29 of Set 15 | micheweni
# Processing Record 30 of Set 15 | lasa
# Processing Record 31 of Set 15 | pemangkat
# Processing Record 32 of Set 15 | fairbanks
# Processing Record 33 of Set 15 | esik
# Processing Record 34 of Set 15 | kandava
# Processing Record 35 of Set 15 | vung tau
# Processing Record 36 of Set 15 | swan river
# Processing Record 37 of Set 15 | huarmey
# Processing Record 38 of Set 15 | saint-leu
# Processing Record 39 of Set 15 | camopi
# Processing Record 40 of Set 15 | bentiu
# Processing Record 41 of Set 15 | irtyshskiy
# Processing Record 42 of Set 15 | paamiut
# Processing Record 43 of Set 15 | gaoua
# Processing Record 44 of Set 15 | bereda
# Processing Record 45 of Set 15 | rio pomba
# Processing Record 46 of Set 15 | viksoyri
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Port Alfred -33.5906   26.8910     57.18        95         100        3.00
# 1   Hammerfest  70.6634   23.6821     43.25       100          75       17.27
# 2       Namibe -15.1961   12.1522     63.46        84          89        9.75
# 3      Barinas   8.6226  -70.2075     87.46        57          96        6.44
# 4     Lorengau  -2.0226  147.2712     80.01        78          68        3.29
# 5   Charleston  32.7766  -79.9309     84.36        80           0        8.01
# 6      Rikitea -23.1203 -134.9692     72.07        69          75       16.84
# 7    Busselton -33.6500  115.3333     51.91        87         100        9.98
# 8        Locri  38.2414   16.2623     68.32        76           8        1.25
# 9      Mataura -46.1927  168.8643     46.47        71         100        2.98
#
#   Country Current Description
# 0      ZA     overcast clouds
# 1      NO       broken clouds
# 2      AO     overcast clouds
# 3      VE     overcast clouds
# 4      PG       broken clouds
# 5      US           clear sky
# 6      PF       broken clouds
# 7      AU          light rain
# 8      IT           clear sky
# 9      NZ       moderate rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Alfred      ZA -33.5906   26.8910     57.18        95         100
# 1     Hammerfest      NO  70.6634   23.6821     43.25       100          75
# 2         Namibe      AO -15.1961   12.1522     63.46        84          89
# 3        Barinas      VE   8.6226  -70.2075     87.46        57          96
# 4       Lorengau      PG  -2.0226  147.2712     80.01        78          68
# ..           ...     ...      ...       ...       ...       ...         ...
# 670   Irtyshskiy      RU  58.3333   68.1333     51.93        93          81
# 671      Paamiut      GL  61.9940  -49.6678     43.21        94         100
# 672        Gaoua      BF  10.2992   -3.2508     73.42        93         100
# 673       Bereda      ES  43.2686   -7.5406     62.42        93         100
# 674    Rio Pomba      BR -21.2747  -43.1792     75.74        35           0
#
#      Wind Speed Current Description
# 0          3.00     overcast clouds
# 1         17.27       broken clouds
# 2          9.75     overcast clouds
# 3          6.44     overcast clouds
# 4          3.29       broken clouds
# ..          ...                 ...
# 670        5.53       broken clouds
# 671        6.11     overcast clouds
# 672        4.41     overcast clouds
# 673        4.43     overcast clouds
# 674        8.08           clear sky
#
# [675 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
